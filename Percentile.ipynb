# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/kakashi/Data Analysis Playground/data_analysis_playground/Income - Sheet1.csv",names=["name","income"],skiprows=[0])

# %%
df
# Out:
#         name    income
# 0        Rob     65000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df.loc[df['name']=='Rob','income'] = 5000

# %%
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df.describe()
# Out:
#              income
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.income.quantile(0.5) # it give 50th percentile
# Out:
# 7000.0

# %%
df.income.quantile(1) # it gives 100th percentile
# Out:
# 10000000.0

# %%
df.income.quantile(0) # it gives 0th percentile
# Out:
# 4000.0

# %%
df.income.quantile(0.25) # it gives 25th percentile
# Out:
# 5500.0

# %%
df.income.quantile(0.75) # it gives 75th percentile
# Out:
# 7750.0

# %% [markdown]
# # Remove outlier

# %%
percentile_99 = df.income.quantile(0.99)

# %%
percentile_99
# Out:
# 9400479.999999994

# %%
df[df.income>percentile_99]
# Out:
#         name    income
# 6  Elon Musk  10000000

# %%
df_no_outlier = df[df.income <= percentile_99]

# %%
df_no_outlier
# Out:
#     name  income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %% [markdown]
# # Handle NA value

# %%
df.loc[df['name']=='Sofia','income'] = np.NaN

# %%
df
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
df.income.mean()
# Out:
# 1671666.6666666667

# %%
df_new = df.fillna(df.income.mean())

# %%
df_new
# Out:
#         name        income
# 0        Rob  5.000000e+03
# 1      Rafiq  6.000000e+03
# 2       Nina  4.000000e+03
# 3      Sofia  1.671667e+06
# 4      Mohan  8.000000e+03
# 5        Tao  7.000000e+03
# 6  Elon Musk  1.000000e+07

# %%
df_new = df.fillna(df.income.median())

# %%
df_new
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia      6500.0
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
df1 = pd.read_csv("/home/kakashi/Data Analysis Playground/data_analysis_playground/archive/AB_NYC_2019.csv")

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df1.price.quantile(0.5)
# Out:
# 106.0

# %%
df1.price.mean()
# Out:
# 152.7206871868289

# %%
df1.price.median()
# Out:
# 106.0

# %%
max_threshold = df1.price.quantile(0.99)

# %%
max_threshold
# Out:
# 799.0

# %%
max_outliers = df1[df1.price > max_threshold ]

# %%
min_threshold = df1.price.quantile(0.05)

# %%
min_threshold
# Out:
# 40.0

# %%
min_outliers = df1[df1.price < min_threshold]

# %%
min_outliers
# Out:
#              id                                              name    host_id  \
# 36        11452                       Clean and Quiet in Brooklyn       7355
# 249       62452                    A SpeciaL!! Private Room in NY     303939
# 250       62461                       B NYC Staten Alternative...     303939
# 251       62787                       C Private Room By The Ferry     303939
# 256       63320                D Private Che@p Room 2 Explore NYC     303939
# ...         ...                                               ...        ...
# 48851  36455649  #7 New Hotel-Like Private Room KING bed near JFK  263504959
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044   The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                      Heaven for you(only for guy)  261338177
# 48871  36475746     A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
#
# ...

# %%
cleaned_dataset = df1[['name','price']][(df1['price']< max_threshold) & (df1['price'] > min_threshold)]

# %%
cleaned_dataset.describe()
# Out:
#               price
# count  45590.000000
# mean     143.632858
# std      102.837434
# min       41.000000
# 25%       75.000000
# 50%      114.000000
# 75%      180.000000
# max      795.000000

# %%
cleaned_dataset.price.median()
# Out:
# 114.0
