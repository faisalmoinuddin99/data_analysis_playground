# %%
import pandas as pd

# %%
df = pd.read_csv("/home/kakashi/Data Analysis Playground/data_analysis_playground/Cars93.csv")

# %%
con = []
cat = []

for i in df.columns:
    if df.dtypes[i] == object:
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['id',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
df['Type'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type'>

# %%
df['AirBags'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Type'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Type'>

# %%
# density plot


df['Type'].value_counts().plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Type'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Type'>

# %%
df['AirBags'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='AirBags'>

# %%
df['Cylinders'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Cylinders'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Cylinders'>

# %%
df['Cylinders'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cylinders'>

# %% [markdown]
# # External Libraries used for visalisation
# ##  seaborn
# ##  matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(data=df, x = 'Cylinders')
# Out:
# <Axes: xlabel='Cylinders', ylabel='count'>

# %%
sns.countplot(data=df, x ='AirBags')
# Out:
# <Axes: xlabel='AirBags', ylabel='count'>

# %%
# Histogram >> for numerical columns

# %%
sns.histplot(data=df, x ='Price',kde=True) # right skiwed distribution
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=df, x = 'id', kde=True) # normal distribution
# Out:
# <Axes: xlabel='id', ylabel='Count'>

# %%
df['id'].mean()
# Out:
# 47.0

# %%
df['id'].median()
# Out:
# 47.0

# %%
df['id'].mode()[0] # because its a descrite columne
# Out:
# 1

# %%
df['Passengers'].median()
# Out:
# 5.0

# %%
df['Passengers'].mean()
# Out:
# 5.086021505376344

# %%
xcon= df[con]

# %%
from matplotlib.pyplot import show

for i in xcon.columns:
    sns.histplot(data=df,x=i, kde=True)
    print(i)
    show()
# Out:
# id
# Min.Price
# Price
# Max.Price
# MPG.city
# MPG.highway
# EngineSize
# Horsepower
# RPM
# Rev.per.mile
# Fuel.tank.capacity
# Passengers
# Length
# Wheelbase
# Width
# Turn.circle
# Rear.seat.room
# Luggage.room
# Weight

# %%
df['Luggage.room'].mean() == df['Luggage.room'].median()
# Out:
# False

# %%
df['Luggage.room'].mean()
# Out:
# 13.890243902439025

# %%
df['Luggage.room'].median()
# Out:
# 14.0

# %%
xcat = df[cat]

# %%
for i in xcat.columns:
    sns.histplot(data=df, x=i, kde=True)
    print(i)
    show()
# Out:
# Manufacturer
# Model
# Type
# AirBags
# DriveTrain
# Cylinders
# Man.trans.avail
# Origin
# Make

# %%
for i in df.columns:
    if df[i].dtypes == object:
        sns.countplot(data=df, x=i)
        print(i)
        show()
    else:
        sns.histplot(data = df, x=i, kde = True)
        print(i)
        show()
# Out:
# id
# Manufacturer
# Model
# Type
# Min.Price
# Price
# Max.Price
# MPG.city
# MPG.highway
# AirBags
# DriveTrain
# Cylinders
# EngineSize
# Horsepower
# RPM
# Rev.per.mile
# Man.trans.avail
# Fuel.tank.capacity
# Passengers
# Length
# Wheelbase
# Width
# Turn.circle
# Rear.seat.room
# Luggage.room
# Weight
# Origin
# Make
