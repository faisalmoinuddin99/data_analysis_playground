# %%
import pandas as pd

# %%
df = pd.read_csv("/home/kakashi/Data Analysis Playground/data_analysis_playground/Cars93.csv")

# %%
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df['Price'].describe()
# Out:
# count    93.000000
# mean     19.509677
# std       9.659430
# min       7.400000
# 25%      12.200000
# 50%      17.700000
# 75%      23.300000
# max      61.900000
# Name: Price, dtype: float64

# %%
# 1. what is the highest price

df['Price'].max()
# Out:
# 61.9

# %%
# 2. what is the lowest price
df['Price'].min()
# Out:
# 7.4

# %%
# 3. show the price in decreasing order
df.sort_values(by='Price',ascending = False)
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# ..  ..            ...       ...      ...        ...    ...        ...
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 79  80         Subaru     Justy    Small        7.3    8.4        9.5
# 52  53          Mazda       323    Small        7.4    8.3        9.1
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 30  31           Ford   Festiva    Small        6.9    7.4        7.9
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
# 4. show the price in increasing order
df.sort_values(by='Price',ascending=True)
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 30  31           Ford   Festiva    Small        6.9    7.4        7.9
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 52  53          Mazda       323    Small        7.4    8.3        9.1
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 79  80         Subaru     Justy    Small        7.3    8.4        9.5
# ..  ..            ...       ...      ...        ...    ...        ...
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
# 5. show the categories presnt in type columns

df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
# 6. show the model having price greater than 40

df[['Model','Price']][df['Price']>40]
# Out:
#       Model  Price
# 10  Seville   40.1
# 47      Q45   47.9
# 58     300E   61.9

# %%
# 7. show the car model having price between 25 to 35 and type midsize or large

df[['Model','Price','Type']][((df['Price']>25)&(df['Price']<35))&((df['Type']=='Midsize')|(df['Type']=='Large'))]
# Out:
#           Model  Price     Type
# 1        Legend   33.9  Midsize
# 4          535i   30.0  Midsize
# 8       Riviera   26.3  Midsize
# 9       DeVille   34.7    Large
# 21     Imperial   29.5    Large
# 48        ES300   28.0  Midsize
# 50  Continental   34.3  Midsize
# 62     Diamante   26.1  Midsize
# 92          850   26.7  Midsize

# %%
df['Horsepower'].describe()
# Out:
# count     93.000000
# mean     143.827957
# std       52.374410
# min       55.000000
# 25%      103.000000
# 50%      140.000000
# 75%      170.000000
# max      300.000000
# Name: Horsepower, dtype: float64

# %%
data = {
    "gender":["Male","Male","Male","Female",'Female',"Male","Female","Female"],
    "salary":[1000,2000,1500,2500,5000,1200,3200,4000]
}

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    gender  salary
# 0    Male    1000
# 1    Male    2000
# 2    Male    1500
# 3  Female    2500
# 4  Female    5000
# 5    Male    1200
# 6  Female    3200
# 7  Female    4000

# %% [markdown]
# # group by >> category wise aggregation

# %%
# what is the highest salary of each gender
df1.groupby(by='gender')['salary'].max()
# Out:
# gender
# Female    5000
# Male      2000
# Name: salary, dtype: int64

# %%
# what is the average salary of each gender
# what is the lowest salary of every gender

# %%
df1.groupby(by='gender')['salary'].mean()
# Out:
# gender
# Female    3675.0
# Male      1425.0
# Name: salary, dtype: float64

# %%
df1.groupby(by='gender')['salary'].median()
# Out:
# gender
# Female    3600.0
# Male      1350.0
# Name: salary, dtype: float64

# %%
df1.groupby(by='gender')['salary'].min()
# Out:
# gender
# Female    2500
# Male      1000
# Name: salary, dtype: int64

# %%
# 10. show the average price for each type of cars
# 11. show the maximium price for every car type

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df.groupby(by='Type')['Price'].mean()
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
df.groupby(by='Type')['Price'].max()
# Out:
# Type
# Compact    31.9
# Large      36.1
# Midsize    61.9
# Small      15.9
# Sporty     38.0
# Van        22.7
# Name: Price, dtype: float64

# %%
# 12. show the average horsepower for each airbags
# 13. show the maximum enginesize for each type of cars
# 14. show average fuel tank capacity for every DriveTrain
# 15. show highest price for each origin
# 16. show average price for every origin

df.groupby(by='AirBags')['Horsepower'].mean()
# Out:
# AirBags
# Driver & Passenger    183.071429
# Driver only           151.904762
# Name: Horsepower, dtype: float64

# %%
df.groupby(by='Type')['EngineSize'].max()
# Out:
# Type
# Compact    3.0
# Large      5.7
# Midsize    4.6
# Small      2.2
# Sporty     5.7
# Van        4.3
# Name: EngineSize, dtype: float64

# %%
df.groupby(by='DriveTrain')['Fuel.tank.capacity'].mean()
# Out:
# DriveTrain
# 4WD      18.410000
# Front    15.855224
# Rear     18.962500
# Name: Fuel.tank.capacity, dtype: float64

# %%
df.groupby(by='Origin')['Price'].max()
# Out:
# Origin
# USA        40.1
# non-USA    61.9
# Name: Price, dtype: float64

# %%
df.groupby(by='Origin')['Price'].mean()
# Out:
# Origin
# USA        18.572917
# non-USA    20.508889
# Name: Price, dtype: float64

# %%
# 17. calculate for every cylinders what is the max weight

df.groupby(by='Cylinders')['Weight'].max()
# Out:
# Cylinders
# 3         2045
# 4         3785
# 5         3960
# 6         4105
# 8         4055
# rotary    2895
# Name: Weight, dtype: int64

# %%
df2 = pd.read_csv("/home/kakashi/Data Analysis Playground/data_analysis_playground/Assignment_pandas_filter/50_Startups.csv")

# %%
df2
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
# 1. show the average profit for each state
# 2. show the higest profit of each state
# 3. show the lowest RND for each state

# %%
df2.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
df2.groupby(by='STATE')['PROFIT'].mean()
# Out:
# STATE
# California    103905.175294
# Florida       118774.024375
# New York      113756.446471
# Name: PROFIT, dtype: float64

# %%
df2.groupby(by='STATE')['PROFIT'].max()
# Out:
# STATE
# California    191792.06
# Florida       191050.39
# New York      192261.83
# Name: PROFIT, dtype: float64

# %%
df2.groupby(by='STATE')['RND'].min()
# Out:
# STATE
# California       0.00
# Florida       1315.46
# New York       542.05
# Name: RND, dtype: float64
